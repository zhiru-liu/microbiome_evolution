# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import random
import os
import scipy
import networkx as nx
import itertools

# %%
os.chdir('..')
from utils import close_pair_utils

# %%
#data_dir = '/Users/Device6/Documents/Research/bgoodlab/fastsimbac/fastSimBac_mac/results'
data_dir = '/media/hdd/Research/fastsimbac' #os.path.join(config.analysis_directory, 'fastsimbac_data')
fig_dir = '/media/hdd/Research/microbiome' #os.path.join(config.analysis_directory, 'run_size_survival_distributions', 'fastSimBac')

# %%
def load_data(filename):
    f = open(os.path.join(data_dir, filename), 'r')
    data = []
    for line in f.read().splitlines()[:-5]:
        parts = line.split('\t')
        if len(parts) != 5:
            continue
        line_data = list(map(int, parts[-1]))
        line_data.append(float(parts[2]))
        data.append(line_data)
    f.close()
    return np.array(data)
        
def compare_two_samples(idx1, idx2, data, genome_len):
    locations = data[:, -1][np.nonzero(data[:, idx1] != data[:, idx2])]
    runs = locations[1:] - locations[:-1]
    runs = runs * genome_len
    return locations, runs.astype(int)

def get_snp_vector(idx1, idx2, data):
    return data[:, idx1] != data[:, idx2]

def get_full_snp_vector(idx1, idx2, data, genome_len):
    v = np.zeros(int(genome_len)).astype(bool)
    snps = data[:, idx1] != data[:, idx2]
    locs = (data[:, -1] * genome_len).astype(int)
    v[locs] = snps
    return v

def get_block_snp_vector(idx1, idx2, data, genome_len=1e6, block_len=1e3):
    bins = np.arange(0, genome_len + 1, block_len)
    locations = data[:, -1][np.nonzero(data[:, idx1] != data[:, idx2])] * genome_len
    snp_vec, _ = np.histogram(locations, bins)
    return snp_vec

# %%
def plot_null(ax):
    # plot the unlinked null
    p = 0.01
    snps = np.random.binomial(1, p, size=int(1e6))
    locations = np.where(snps == 1)[0]
    run_lengths = locations[1:] - locations[:-1]
    p_emp = sum(snps) / 1e6
    _ = ax.hist(run_lengths * p_emp, density=True, bins=50, cumulative=-1, histtype='step', color='k')
    ax.plot([], color='k', label='independent null')


def plot_one_simulation(ax, filename, genome_len=1e6, num_curves=500, color='b', label=None, cutoff=None):
    data = load_data(filename)
    
    sample_size = data.shape[1] - 1
    pairs = [random.sample(range(sample_size), 2) for i in range(num_curves)]

    # plot the simulation
    divergences = []
    for pair in pairs:
        snp_locs, run_lens = compare_two_samples(pair[0], pair[1], data, genome_len)
        snp_count = len(snp_locs)
        div = snp_count / genome_len
        divergences.append(div)
        if cutoff:
            if div < cutoff:
                continue
        _ = ax.hist(run_lens * div, bins=100, cumulative=-1, histtype='step', color=color, density=True, alpha=0.1)
    ax.plot([], color=color, label=label)
    return np.array(divergences)

# %%
def count_local_haplotypes_BSMC(haps, locations, start_idx, end_idx, snp_tol=1):
    mask = (locations >= start_idx) & (locations < end_idx)
    hap = haps[mask, :]
    # perform (dumb) pairwise comparison
    res = np.zeros((hap.shape[1], hap.shape[1]))
    for i in range(hap.shape[1]):
        for j in range(hap.shape[1]):
            v = hap[:, i] != hap[:, j]
            res[i, j] = np.sum(v)
    G = nx.from_numpy_matrix(res <= snp_tol)
    components = map(list, sorted(nx.connected_components(G), key=len, reverse=True))
    return components

# %% [markdown]
# ## Run lengths distribution plotting

# %%
genome_len = 5e5
plt.figure(figsize=(8,6), dpi=600)

ax = plt.gca()
ax.set_yscale('log')

plot_null(ax)

colors = sns.color_palette()

all_divs = []

ax.set_xlim([0, 25])

rs = [0.001, 0.005, 0.01, 0.02]
ts = [0.01]
ls = [5000, 10000]
r = rs[0]
t = ts[0]
for j in range(0, 2):
    lam = ls[j]
    filename = 'varying_rho/num_samples_100_genomelen_5e+05_r_%.3f_t_%.3f_tractlen_%d.txt' % (r, t, lam)
    divs = plot_one_simulation(ax, filename, num_curves=100, color=colors[j], label='l=%d'%lam)
    all_divs.append(divs)

ax.set_title('Bacterial Sequential Markov Coalescence')
ax.set_xlabel('Rescaled run lengths')
ax.set_ylabel('Survival proba')
ax.legend()

#plt.savefig(os.path.join(fig_dir, 'num_samples_100_genomelen_1e+06_r_%.3f_t_%.3f.pdf'%(r, t)))

# %%
sample_size = 100
sim_data = load_data(filename)
divergences = []
pairs = []
for i in range(sample_size - 1):
        for j in range(i + 1, sample_size):
            snp_locs, run_lens = compare_two_samples(i, j, sim_data, genome_len)
            snp_count = len(snp_locs) + 1
            div = snp_count / genome_len
            divergences.append(div)
            pairs.append((i, j))
divergences = np.array(divergences)
pairs = np.array(pairs)

plt.figure()
sns.distplot(divergences, bins=100, kde=False)
print("pi is %.4f " % np.mean(divergences))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-99-0eda5707b402> in <module>()
#       1 sample_size = 100
# ----> 2 sim_data = load_data(filename)
#       3 divergences = []
#       4 pairs = []
#       5 for i in range(sample_size - 1):
#
# <ipython-input-4-6d74a6b41f02> in load_data(filename)
#       1 def load_data(filename):
# ----> 2     f = open(os.path.join(data_dir, filename), 'r')
#       3     data = []
#       4     for line in f.read().splitlines()[:-5]:
#       5         parts = line.split('\t')
#
# IOError: [Errno 2] No such file or directory: '/media/hdd/Research/fastsimbac/clonal/num_samples_2_genomelen_1e+06_r_0.000_t_0.010_tractlen_5000_rep_0.txt'

# %%
# grid of run lengths distributions
fig, axs = plt.subplots(3, 3, figsize=(12, 9), dpi=600)

rs = [0.005, 0.01, 0.02]
ts = [0.001, 0.005, 0.01]
ls = [1000, 5000, 10000, 20000]

colors = sns.color_palette()

for i in range(3):
    for j in range(3):
        ax = axs[i, j]
        ax.set_xlim([0, 25])
        ax.set_yscale('log')
        plot_null(ax)
        r = rs[i]
        t = ts[j]
        for k in range(len(ls)):
            lam = ls[k]
            filename = 'parameter_space/num_samples_100_genomelen_1e+06_r_%.3f_t_%.3f_tractlen_%d.txt' % (r, t, lam)
            try:
                divs = plot_one_simulation(ax, filename, num_curves=100, color=colors[k], label='l=%d'%lam, cutoff=0.8 * t)
            except IOError:
                print("Skipping bad r_%.3f_t_%.3f_tractlen_%d" % (r, t, lam))
                continue
        ax.legend()
for i in range(3):
    axs[i, 0].set_ylabel('r=%.3f'%rs[i])
    axs[0, i].set_title('t=%.3f'%ts[i])
axs[2, 1].set_xlabel('Normalized run lengths')
plt.tight_layout()
fig.savefig(os.path.join(fig_dir, 'param_scan.pdf'))
plt.close()

# %%
#Investigate the peak
data = load_data(filename)

# %%
while True:
    idx1, idx2 = random.sample(range(100), 2)
    snp_vec = get_block_snp_vector(idx1, idx2, data)
    div = np.sum(snp_vec) / 1e6
    if div > 0.01:
        continue
    else:
        print(div)
        plt.plot(snp_vec)
        break

# %% [markdown]
# ## Clonal simulation

# %%
sample_size = 100
genome_len = 1e6
for i in range(1, 11):
    divergences = []
    pairs = []
    filename = 'clonal/100/num_samples_100_genomelen_1e+06_r_0.000_t_0.010_tractlen_5000_rep_{}.txt'.format(i)
    sim_data = load_data(filename)
    for i in range(sample_size - 1):
        for j in range(i + 1, sample_size):
            snp_locs, run_lens = compare_two_samples(i, j, sim_data, genome_len)
            snp_count = len(snp_locs) + 1
            div = snp_count / genome_len
            divergences.append(div)
            pairs.append((i, j))
    divergences = np.array(divergences)
    pairs = np.array(pairs)

    plt.figure()
    sns.distplot(divergences, bins=100, kde=False)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-89-eeba5137ee50> in <module>()
#       5     pairs = []
#       6     filename = 'clonal/100/num_samples_100_genomelen_1e+06_r_0.005_t_0.010_tractlen_5000_rep_{}.txt'.format(i)
# ----> 7     sim_data = load_data(filename)
#       8     for i in range(sample_size - 1):
#       9         for j in range(i + 1, sample_size):
#
# <ipython-input-30-6d74a6b41f02> in load_data(filename)
#       1 def load_data(filename):
# ----> 2     f = open(os.path.join(data_dir, filename), 'r')
#       3     data = []
#       4     for line in f.read().splitlines()[:-5]:
#       5         parts = line.split('\t')
#
# IOError: [Errno 2] No such file or directory: '/media/hdd/Research/fastsimbac/clonal/100/num_samples_100_genomelen_1e+06_r_0.005_t_0.010_tractlen_5000_rep_1.txt'

# %%
gene_bins = np.arange(0, 1e6 + 1, 1000)
clonal_counts = []
recomb_counts = []
clonal_threshold = 1
for pair in pairs[np.nonzero(divergences < 0.0005)[0]]:
    snp_locs, run_lens = compare_two_samples(pair[0], pair[1], sim_data, genome_len)
    snps = snp_locs * genome_len
    histo = np.histogram(snps.astype(int), bins=gene_bins)
    snp_genes = histo[0]
    clonal_counts.append(len(np.nonzero((snp_genes <= clonal_threshold) & (snp_genes !=0))[0]))
    recomb_counts.append(len(np.nonzero(snp_genes > clonal_threshold)[0]))
    #plt.figure()
    #plt.plot(histo[0])

# %%
plt.plot(clonal_counts, recomb_counts, '.')
slope, intercept, _, _, _ = scipy.stats.linregress(clonal_counts, recomb_counts)
xs = np.linspace(0, max(clonal_counts), 100)
plt.plot(xs, slope * xs + intercept, label="slope=%f"%slope)
plt.legend()

# %%
np.mean(divergences)

# %%
sns.distplot(divergences, bins=200, kde=False)

# %%
#filename = 'clonal.txt'
filename = 'varying_rho/num_samples_100_genomelen_5e+05_r_0.005_t_0.010_tractlen_5000.txt'
sim_data = load_data(filename)
genome_len=500000.
sample_size=100
pairs = []
divergences = []
for i in range(sample_size - 1):
    for j in range(i + 1, sample_size):
        snp_locs, run_lens = compare_two_samples(i, j, sim_data, genome_len)
        snp_count = len(snp_locs) + 1
        div = snp_count / genome_len
        divergences.append(div)
        pairs.append((i, j))

# %%
sns.distplot(divergences, kde=False, bins=100)
plt.xlabel('pairwise divergence')
plt.ylabel('counts')
# Out:
# Text(0,0.5,'counts')

# %%
pairs = np.array(pairs)
divergences = np.array(divergences)

# %%
pairs[divergences < 0.0005]
# Out:
# array([[ 2, 19],
#        [ 4, 69],
#        [ 6, 31],
#        [ 7, 99],
#        [21, 25],
#        [23, 95],
#        [30, 33],
#        [36, 60],
#        [42, 98],
#        [64, 73]])

# %%
genome_len = 5e5

# %%
singles = []    
nonzeros = []    
snps = []    
num_blocks = []  
block_len = 500
for pair in pairs[divergences < 0.008]:
    snp_vec = get_full_snp_vector(pair[0], pair[1], sim_data, genome_len)
    blocks = close_pair_utils.to_block(snp_vec, block_len)
    snps.append(np.sum(snp_vec))    
    singles.append(sum(blocks == 1))    
    nonzeros.append(sum(blocks >= 1))    
    num_blocks.append(len(blocks))    
df = pd.DataFrame()    
df['single_snp_blocks'] = singles    
df['snp_blocks'] = nonzeros    
df['num_snps'] = snps    
df['num_total_blocks'] = num_blocks

# %%
df.plot.scatter('snp_blocks', 'num_snps')
xs = np.linspace(0, 499)
ys = -500 * np.log((1000-xs)/1000)
plt.plot(xs, ys, 'r')

# %%
snp_vec = get_full_snp_vector(2, 19, sim_data, genome_len)
blocks = close_pair_utils.to_block(snp_vec, block_len)
plt.plot(blocks)

# %% [markdown]
# ## Pairwise clonal simulation

# %%
divergences = []
for i in range(1, 5001):
    filename = 'clonal/num_samples_2_genomelen_1e+06_r_0.000_t_0.010_tractlen_5000_rep_{}.txt'.format(i)
    sim_data = load_data(filename)
    snp_locs, run_lens = compare_two_samples(0, 1, sim_data, genome_len)
    snp_count = len(snp_locs) + 1
    div = snp_count / genome_len
    divergences.append(div)

# %%
pairs = np.array(pairs)
divergences = np.array(divergences)

# %% [markdown]
# ## Pile up plots

# %%
def compute_pile_up_BSMC(sim_data, genome_len, close_pair_cutoff=0.005, run_len_thresholds=[4000, 6000, 8000]):
    cumu_runs = np.zeros([int(genome_len), len(run_len_thresholds)])
    sample_size = sim_data.shape[1] - 1
    reps = 0
    for i in range(sample_size):
        for j in range(i+1, sample_size):
            site_locations, runs = compare_two_samples(i, j, sim_data, genome_len)
            site_locations = np.array(site_locations * genome_len).astype(int)
            div = len(site_locations) / genome_len
            if div < close_pair_cutoff:
                continue
            runs = site_locations[1:] - site_locations[:-1]
            for k in range(len(run_len_thresholds)):
                threshold = run_len_thresholds[k]
                event_starts = site_locations[:-1][runs > threshold]
                event_ends = site_locations[1:][runs > threshold]
                for start, end in zip(event_starts, event_ends):
                    cumu_runs[start:end, k] += 1
            reps += 1
    return cumu_runs, reps

# %%
cumu_runs, reps = compute_pile_up_BSMC(sim_data, genome_len)

# %%
r = 0.001
t = 0.010
lam = 5000
genome_len = 5e5
filename = 'varying_rho/num_samples_100_genomelen_5e+05_r_%.3f_t_%.3f_tractlen_%d.txt' % (r, t, lam)
sim_data = load_data(filename)

# %%
fig, axes = plt.subplots(1, 2, figsize=(4, 2), sharey=True, gridspec_kw={'width_ratios':[4, 1]}, dpi=300)
i = 2
dat = cumu_runs[:, i] / float(reps)
axes[0].plot(dat, linewidth=1)
_ = axes[1].hist(dat, bins=50, orientation='horizontal')
print(np.mean(dat))
print(np.var(dat))
print(np.std(dat) / np.mean(dat))
# Out:
# 0.0006818528756130184
# 1.3300055068404225e-06
# 1.691359952021745

# %% [markdown]
# ### Compute coefficient of variation

# %%
rs = [0.001, 0.005, 0.010, 0.015, 0.020]
t = 0.010
lams = [5000, 10000]
ls = [4000, 5000, 6000, 7000, 8000]

markers = itertools.cycle(('^', 'x'))
for i in range(len(rs)):
    r = rs[i]
    c = plt.get_cmap("tab10")(i)
    for lam in lams:
        filename = 'varying_rho/num_samples_100_genomelen_5e+05_r_%.3f_t_%.3f_tractlen_%d.txt' % (r, t, lam)
        sim_data = load_data(filename)
        cumu_runs, reps = compute_pile_up_BSMC(sim_data, genome_len, run_len_thresholds=ls)
        pileup = cumu_runs / reps
        cv = np.std(pileup, axis=0) / np.mean(pileup, axis=0)
        plt.plot(ls, cv, linestyle="None", marker=next(markers), color=c, label='%f'%r)
plt.figlegend()

# %% [markdown]
# ### Pile-up with H1/H12

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 4), dpi=300)
axes[1].set_ylim([0, 0.07])
locs = np.array(sim_data[:, -1] * genome_len).astype(int)
has_snp = np.zeros(int(genome_len))
has_snp[locs] = 1
snp_window = 10000
axes[0].plot(np.convolve(has_snp, np.ones(snp_window)/snp_window, mode='Same'))
for i in range(3):
    axes[1].plot(cumu_runs[:, i] / float(reps))

# %%
def compute_theta_est(n, S_n, L):
    # n: sample size
    # S_n: number of segragating sites
    # L: number of sites in this locus
    factor = np.sum(np.reciprocal(np.arange(1, n), dtype=float))
    return float(S_n) / factor / L

# %%
print("S estimate for theta is %.3f" % compute_theta_est(100, np.sum(has_snp), genome_len))
# Out:
# S estimate for theta is 0.010

# %%
# %%time
# computing the sliding window analysis
window_size = 4000
stride = 1000
start = 0
all_fracs = []
import time
t0 = time.time()
while start < genome_len:
    end = min(genome_len, start + window_size)
    cs = count_local_haplotypes_BSMC(sim_data[:, :-1], sim_data[:, -1] * genome_len, start, end)
    frac = np.array(map(len, cs)) / float(sample_size)
    all_fracs.append(frac)
    start += stride
    if start % 10000 == 0:
        print("{:.2}% at {:.2} secs".format(100 * float(start) / genome_len, time.time() - t0))
# Out:
# 2.0% at 0.53 secs
# 4.0% at 1.0 secs
# 6.0% at 1.6 secs
# 8.0% at 2.1 secs
# 1e+01% at 2.6 secs
# 1.2e+01% at 3.2 secs
# 1.4e+01% at 3.7 secs
# 1.6e+01% at 4.2 secs
# 1.8e+01% at 4.7 secs
# 2e+01% at 5.3 secs
# 2.2e+01% at 5.8 secs
# 2.4e+01% at 6.3 secs
# 2.6e+01% at 6.9 secs
# 2.8e+01% at 7.4 secs
# 3e+01% at 7.9 secs
# 3.2e+01% at 8.4 secs
# 3.4e+01% at 9.0 secs
# 3.6e+01% at 9.5 secs
# 3.8e+01% at 1e+01 secs
# 4e+01% at 1.1e+01 secs
# 4.2e+01% at 1.1e+01 secs
# 4.4e+01% at 1.2e+01 secs
# 4.6e+01% at 1.2e+01 secs
# 4.8e+01% at 1.3e+01 secs
# 5e+01% at 1.3e+01 secs
# 5.2e+01% at 1.4e+01 secs
# 5.4e+01% at 1.4e+01 secs
# 5.6e+01% at 1.5e+01 secs
# 5.8e+01% at 1.5e+01 secs
# 6e+01% at 1.6e+01 secs
# 6.2e+01% at 1.6e+01 secs
# 6.4e+01% at 1.7e+01 secs
# 6.6e+01% at 1.7e+01 secs
# 6.8e+01% at 1.8e+01 secs
# 7e+01% at 1.9e+01 secs
# 7.2e+01% at 1.9e+01 secs
# 7.4e+01% at 2e+01 secs
# 7.6e+01% at 2e+01 secs
# 7.8e+01% at 2.1e+01 secs
# 8e+01% at 2.1e+01 secs
# 8.2e+01% at 2.2e+01 secs
# 8.4e+01% at 2.2e+01 secs
# 8.6e+01% at 2.3e+01 secs
# 8.8e+01% at 2.3e+01 secs
# 9e+01% at 2.4e+01 secs
# 9.2e+01% at 2.4e+01 secs
# 9.4e+01% at 2.5e+01 secs
# 9.6e+01% at 2.5e+01 secs
# 9.8e+01% at 2.6e+01 secs
# 1e+02% at 2.6e+01 secs
# CPU times: user 26.4 s, sys: 163 ms, total: 26.6 s
# Wall time: 26.4 s

# %%
import pandas as pd
df = pd.DataFrame()
df['Start'] = np.arange(0, genome_len, stride)
df['End'] = np.minimum(df['Start'] + window_size, genome_len)
df['MaxFrac'] = map(max, all_fracs)
df['Heterozygosity'] = map(lambda x: np.sum(x*x), all_fracs)
df['MaxFrac^2'] = df['MaxFrac'] ** 2
df['H12'] = map(lambda x: np.sum(x*x) + 2*x[0]*x[1] if len(x) > 1 else x[0]**2, all_fracs)
df['H2'] = map(lambda x: np.sum(x*x) - x[0]**2, all_fracs)

# %%
from matplotlib import cm # for color map

fig, axes = plt.subplots(4, 1, figsize=(8, 6), dpi=300)
snp_window = 10000
# axes[0].plot(np.convolve(has_snp, np.ones(snp_window)/snp_window, mode='Same'))
for i in range(3):
    axes[1].plot(cumu_runs[:, i] / 4950, label=thresholds[i])

from scipy.interpolate import interp1d
y = np.array(df['H2'] / df['Heterozygosity'])
x = np.array((df['Start'] + df['End']) / 2).astype(int)
f = interp1d(x, y)
xnew = np.arange(min(x), max(x))
c_val = cumu_runs[xnew, 0]
axes[3].scatter(xnew, f(xnew), s=1, c=cm.Blues(np.abs(c_val / max(c_val))), label='H2/H1')

axes[2].plot(x[:-4], df['Heterozygosity'][:-4], '.', markersize=1, label='Heterozygosity (H1)')
axes[2].plot(x[:-4], df['H12'][:-4], '.', markersize=1, label='H12')

for i in range(3):
    axes[i].set_xticklabels([])
axes[3].set_ylim([0, 1])
axes[1].legend()
axes[2].legend()
axes[0].set_ylabel('SNP density')
axes[1].set_ylabel('Frac of pairs sharing')
axes[3].set_ylabel('H2 / H1')
axes[3].set_xlabel('Core gene 4D location')
plt.tight_layout()

# %%
_ = plt.hist(df['Heterozygosity'][:-4], bins=100)
print(np.mean(df['Heterozygosity'][:-4]), np.std(df['Heterozygosity'][:-4]))
# Out:
# (0.019310483870967742, 0.002641490248630652)

# %% [markdown]
# ## Coarse-graining into blocks (fake genes)

# %%
os.chdir('/Users/Device6/Documents/Research/bgoodlab/microbiome_evolution/')
from utils import HGT_utils
import config

# %%
filename1 = 'parameter_space/num_samples_100_genomelen_1e+06_r_0.005_t_0.001_tractlen_1000.txt'
data = load_data(filename1)

# %%
all_runs_map = dict()
snp_counts_map = dict()
for i in range(100):
    for j in range(i+1, 100):
        snp_vec = get_block_snp_vector(i, j, data, genome_len=1e6, block_len=1e3)
        res = HGT_utils.find_runs(snp_vec)
        all_runs_map[(i, j)] = res
        snp_counts_map[(i, j)] = sum(snp_vec)

# %%
thresholds = [0, 5, 10, 15]
final_cumu_runs = HGT_utils.cumulate_runs_by_thresholds(
    all_runs_map, snp_counts_map, (-1, 1e6), 1000, thresholds)

# %%
fig = plt.figure()
ax = plt.gca()
for i in range(len(thresholds)):
    ax.plot(final_cumu_runs[i], label="Threshold %d" % thresholds[i])
    print(max(final_cumu_runs[i]))
ax.legend()
ax.set_ylim((0, len(all_runs_map)))
ax.figure.set_size_inches(12, 4)
ax.set_title('Cumulative long runs per gene')
ax.set_xlabel('Gene id')
ax.set_ylabel('Num runs')
#fig.savefig(os.path.join(config.analysis_directory, 'IBS_locations', 'synthetic/recombinant_r_0.010_t_0.010_tractlen_500.pdf'), dpi=600)

# %%
for filename in os.listdir(os.path.join(data_dir, "parameter_space")):
    if filename.startswith('.'):
        continue
    else:
        filename_base = filename.split('.')[0]
        data = load_data(os.path.join("parameter_space", filename))
        
        all_runs_map = dict()
        snp_counts_map = dict()
        for i in range(100):
            for j in range(i+1, 100):
                snp_vec = get_block_snp_vector(i, j, data, genome_len=1e6, block_len=1e3)
                res = HGT_utils.find_runs(snp_vec)
                all_runs_map[(i, j)] = res
                snp_counts_map[(i, j)] = sum(snp_vec)
                
        thresholds = [0, 5, 10, 15]
        final_cumu_runs = HGT_utils.cumulate_runs_by_thresholds(
            all_runs_map, snp_counts_map, (-1, 1e6), 1000, thresholds)
        
        fig = plt.figure()
        ax = plt.gca()
        for i in range(len(thresholds)):
            ax.plot(final_cumu_runs[i], label="Threshold %d" % thresholds[i])
            print(max(final_cumu_runs[i]))
        ax.legend()
        ax.set_ylim((0, len(all_runs_map)))
        ax.figure.set_size_inches(12, 4)
        ax.set_title('Cumulative long runs per gene')
        ax.set_xlabel('Gene id')
        ax.set_ylabel('Num runs')
        fig.savefig(os.path.join(
            config.analysis_directory, 'IBS_locations', 'synthetic', "parameter_space",
        "%s.png"%filename), dpi=600)
        plt.close()
        
        fig = plt.figure()
        ax = plt.gca()
        ax.set_xlim([0, 1])
        for i in range(1, 4):
            _ = ax.hist(final_cumu_runs[i] / final_cumu_runs[0], cumulative=-1,
                        bins=100, density=True, label="Threshold %d" % thresholds[i])
        ax.legend()
        fig.savefig(os.path.join(
            config.analysis_directory, 'IBS_locations', 'synthetic', "ratios",
        "%s.png"%filename), dpi=600)
        plt.close()

# %%
# polarize data
genotype = np.sum(data[:, :100], axis=1).astype(int) / 50

# %%
polarized_data = data.copy()

# %%
polarized_data[genotype == 1] = 1 - data[genotype == 1]

# %%
marked_haplotypes = np.zeros((data.shape[1] - 1, 999 + data.shape[0], 3))
snp_idx = 0
block_size = 1000
curr_block = 0
block_snps = {}
block_snps[0] = []
for i in range(data.shape[0]):
    location = data[i, -1] * 1e6
    if int(location) / block_size > curr_block:
        marked_haplotypes[:, snp_idx, 1] = 1
        block_snps[curr_block] = np.array(block_snps[curr_block])
        snp_idx += 1
        curr_block += 1
        block_snps[curr_block] = []
    marked_haplotypes[:, snp_idx, 0] = polarized_data[i, :-1]
    marked_haplotypes[:, snp_idx, 2] = 1 - polarized_data[i, :-1]
    block_snps[curr_block].append(polarized_data[i, :-1])
    snp_idx += 1

# %%
int(data[100, -1] * 1e6) / block_size

# %%
block_snps[0].shape

# %%
marked_haplotypes.shape

# %%
fig = plt.figure()
fig.set_size_inches((60, 4))
plt.imshow(marked_haplotypes[flat_array, :500, :])

# %%
def pairwise_divergence(haplotype_arr):
    # haplotype_arr: (num_sites, num_samples)
    num_samples = haplotype_arr.shape[1]
    dm = np.zeros((num_samples, num_samples))
    for i in range(num_samples):
        for j in range(i+1, num_samples):
            dm[i, j] = np.sum(haplotype_arr[:, i] != haplotype_arr[:, j])
            dm[j, i] = np.sum(haplotype_arr[:, i] != haplotype_arr[:, j])
    return dm

def matrix_to_clusters(distance_matrix, allowed_snps=0):
    # return a list of list of indices. Each sublist is a cluster of haplotypes
    G = nx.from_numpy_matrix(distance_matrix <= allowed_snps)
    clusters = get_cluster_members(G)
    return [list(c) for c in clusters]

def get_cluster_members(G):
    sub_graphs = nx.connected_component_subgraphs(G)
    clusters = []
    for i, sg in enumerate(sub_graphs):
        clusters.append(sg.nodes)
    return clusters

# %%
dist_m = pairwise_divergence(block_snps[6])
print(dist_m[0, 1])
clusters = matrix_to_clusters(dist_m)
cluster_sizes = [len(x) for x in clusters]
shared_pairs = np.sum([x*(x-1)/2 for x in cluster_sizes])
print(shared_pairs)
print(final_cumu_runs[0][6])
flat_array = np.array([x for c in clusters for x in c])

# %%
ax = plt.gca()
for i in range(1000):
    dist_m = pairwise_divergence(block_snps[i])
    _ = ax.hist(dist_m.flatten(), cumulative=-1, histtype='step', alpha=0.1)

# %%
_ = plt.hist(final_cumu_runs[0], bins=100)

# %% [markdown]
# ## Getting local trees

# %%
from Bio import Phylo
from cStringIO import StringIO

# %%
filename = 'trees.txt'
data_dir = '/Users/Device6/Documents/Research/bgoodlab/fastsimbac/fastSimBac_mac/'

# %%
f = open(os.path.join(data_dir, filename))
f.seek(0)
tree = Phylo.read(StringIO(tree_str), 'newick')
Phylo.draw(tree)

# %%
import itertools

# %%
def newick_to_matrix(newick_str):
    tree = Phylo.read(StringIO(newick_str), 'newick')
    num_leaves = len(tree.get_terminals())
    distance = np.zeros((num_leaves, num_leaves))
    for x, y in itertools.combinations(tree.get_terminals(), 2):
        i = int(x.name)
        j = int(y.name)
        distance[i, j] = tree.distance(x, y)
    return distance

def parse_line(line_str):
    s = line.split(';')[0]
    length = int(s[1:s.find(']')])
    tree_str = s[s.find(']')+1:]
    return length, tree_str

# %%
import time
t0 = time.time()
loc = 0
tree_idx = 0
for line in f:
    if not line.startswith('['):
        continue
    l, tree_str = parse_line(line)
    with open('./trees/{}_{}.txt'.format(tree_idx, l), 'w') as save:
        save.write(tree_str)
    loc += l
    tree_idx += 1

# %% [markdown]
# ## Experiment with Zarr saving

# %%
data_dir = '/Users/Device6/Documents/Research/bgoodlab/fastsimbac/'
csv_dir = os.path.join(data_dir, 'postprocessing', 'matrices')

# %%
filenames = filter(lambda x: not x.startswith('.'), os.listdir(csv_dir))

# %%
filenames = sorted(filenames, key=lambda x: int(x.split('_')[0]))
spans = np.array(map(lambda x: int(re.findall('_([0-9]+).', x)[0]), filenames))

# %%
zz = zarr.open('data/example.zarr', mode='w', shape=(100, 100, len(spans)), chunks=(10, 10, 100), dtype='i4')

# %%
# %%time
curr_loc=0
for i, name in enumerate(filenames):
    span = int(re.findall('_([0-9]+).', name)[0])
    arr = np.loadtxt(os.path.join(csv_dir, name), delimiter=',')
    z1[:, :, i] = arr
    if i > 100:
        break

# %%
arr = np.loadtxt(os.path.join(csv_dir, filenames[0]), delimiter=',')

# %%
a = np.zeros((100, 100, 5))

# %%
a[:, :, :3] = np.repeat(arr[:, :, None], 3, axis=2)

# %%
curr_loc

# %%
np.savetxt('spans.txt', spans)
